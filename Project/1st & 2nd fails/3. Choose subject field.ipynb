# %%
a1  =  [1  *  0.65 , 7, 26  *  0.75 , 28 *  0.5] 
a2  =  [2  *  0.65 , 6, 27  *  0.75 , 27 *  0.5]
a3  =  [3  *  0.65 , 16, 24 *  0.75 , 13 *  0.5]
a5  =  [5  *  0.65 , 1, 10  *  0.75 , 19 *  0.5]
a6  =  [6  *  0.65 , 12, 13 *  0.75 , 9 *  0.5 ]
a7  =  [7  *  0.65 , 5, 12  *  0.75 , 4 *  0.5 ]
a11 =  [11 *  0.65 , 2, 22  *  0.75 , 15 *  0.5]
a13 =  [13 *  0.65 , 10, 16 *  0.75 , 23 *  0.5]
a14 =  [14 *  0.65 , 11, 11 *  0.75 , 12 *  0.5]
a15 =  [15 *  0.65 , 8, 14  *  0.75 , 16 *  0.5]
a17 =  [17 *  0.65 , 9, 9   *  0.75 , 6 *  0.5 ]
a18 =  [18 *  0.65 , 3, 5   *  0.75 , 5  *  0.5]
a19 =  [19 *  0.65 , 4, 4   *  0.75 , 8  *  0.5]

# Create a list of matrices with their names
matrices = {
    "a1": a1,
    "a2": a2,
    "a3": a3,
    "a5": a5,
    "a6": a6,
    "a7": a7,
    "a11": a11,
    "a13": a13,
    "a14": a14,
    "a15": a15,
    "a17": a17,
    "a18": a18,
    "a19": a19,
}

# Calculate and print the sum of items for each matrix
for name, matrix in matrices.items():
    total = sum(matrix)
    print(f"sum {name}:  {total/4:.2f}")


print("                                                         ")
print("     ****************************************         ")
print("                                                         ")

# Calculate sums and store them in a list of tuples
indexed_sums = [(name, sum(matrix)) for name, matrix in matrices.items()]

# Sort the list by the sums
sorted_sums = sorted(indexed_sums, key=lambda x: x[1])

# Print the sorted results
for name, total in sorted_sums:
    print(f"sum {name}: {total/4:.2f}")
# Out:
# sum a1:  10.29
# sum a2:  10.26
# sum a3:  10.61
# sum a5:  5.31
# sum a6:  7.54
# sum a7:  5.14
# sum a11:  8.29
# sum a13:  10.49
# sum a14:  8.59
# sum a15:  9.06
# sum a17:  7.45
# sum a18:  5.24
# sum a19:  5.84
#
#      ****************************************
#
# sum a7: 5.14
# sum a18: 5.24
# sum a5: 5.31
# sum a19: 5.84
# sum a17: 7.45
# sum a6: 7.54
# sum a11: 8.29
# sum a14: 8.59
# sum a15: 9.06
# sum a2: 10.26
# sum a1: 10.29
# sum a13: 10.49
# sum a3: 10.61

# %%
#a1  =  pattern Based on Rule-based Extraction
#a2  =  POS Tagging for Extraction
#a3  =  unsupervised KE techniques
#a5  =  Hybrid approaches combining supervised and unsupervised techniques
#a6  =  multi label TC
#a7  =  sentiment analysis for social media
#a11 =  Keyword Ranking and Scoring Innovations
#a13 =  Domain Specific KE
#a14 =  Domain Specific TC
#a15 =  Explainable TC
#a17 =  data augmentation for TC
#a18 =  Embedding based KE
#a19 =  few shot and zero shot learning
